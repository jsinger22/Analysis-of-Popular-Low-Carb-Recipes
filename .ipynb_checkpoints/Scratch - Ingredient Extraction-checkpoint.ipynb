# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
ingredients = pd.read_csv('ingredients.csv')

# %%
ingredients.head()
# Out:
#    Unnamed: 0                                        recipe_name  \
# 0           0  Mushroom Rarebit with Poached Eggs - Recipe - ...
# 1           1  Mushroom Rarebit with Poached Eggs - Recipe - ...
# 2           2  Mushroom Rarebit with Poached Eggs - Recipe - ...
# 3           3  Mushroom Rarebit with Poached Eggs - Recipe - ...
# 4           4  Mushroom Rarebit with Poached Eggs - Recipe - ...
#
#                        ingredients
# 0                     3 large eggs
# 1  1/3 cup shredded cheddar cheese
# 2            1/2 tsp Dijon mustard
# 3     2 drops Worcestershire sauce
# 4              1 tbsp Greek yogurt

# %%
# drop the 'Unnamed: 0' column
ingredients.drop('Unnamed: 0',axis=1,inplace=True)
ingredients.head(2)
# Out:
#                                          recipe_name  \
# 0  Mushroom Rarebit with Poached Eggs - Recipe - ...
# 1  Mushroom Rarebit with Poached Eggs - Recipe - ...
#
#                        ingredients
# 0                     3 large eggs
# 1  1/3 cup shredded cheddar cheese

# %%
# perform same cleaning steps to recipe_name as we did for recipes dataframe
ingredients['recipe_name'] = ingredients['recipe_name'].str.replace('- Recipe - Diet Doctor','').str.replace('- Diet Doctor','').str.replace('- Recipe','').str.strip()

# %%
len(ingredients['recipe_name'].unique())
# Out:
# 1131

# %%
def first_10_matches(pattern):
    """
    Return the first 10 ingredients that match
    the provided regular expression
    """
    ingredient_names = ingredients['ingredients']
    all_matches = ingredient_names[ingredient_names.str.contains(pattern)]
    first_10 = all_matches.head(10)
    return first_10

# %% [markdown]
# Ingredients are generally in the format: [quantity] [unit of measurement] [ingredient name] e.g. 1 tbsp Greek yogurt.
#
# Let's parse out each component, and isolate the ingredient names.

# %% [markdown]
# Scratch:
#
# When we scraped the ingredients, we split the ingredient list by commas. Looks like some individual ingredients included a comma and are thus split between multiple rows.
#
# It appears that the information after the comma does not contain the actual ingredient, but is rather a supplemental description. Therefore, we will drop these rows.

# %%
first_10_matches(r"[0-9]/?[0-9]?[\s]?oz.?")
# Out:
# 5     12 oz. portobello mushrooms about 1 large cap ...
# 16                                   1 1/2 oz. cucumber
# 18                 4 oz. deli turkey or smoked deli ham
# 23                                       5 oz. zucchini
# 25                              1 1/2 oz. celery stalks
# 28                                6 oz. deli roast beef
# 29                       6 oz. rotisseri chicken (meat)
# 30                                  3 oz. green cabbage
# 37                                  5 oz. tuna in water
# 39                                    1/2 oz. scallions
# Name: ingredients, dtype: object

# %%
# appears to capture all rows
first_10_matches(r"[0-9]/?[0-9]?[\s]?oz.?|tsp?|tbsp?|pinch?|cups?|cup?|lb?|lbs?|drops?")
# Out:
# 0                                         3 large eggs
# 1                      1/3 cup shredded cheddar cheese
# 2                                1/2 tsp Dijon mustard
# 3                         2 drops Worcestershire sauce
# 4                                  1 tbsp Greek yogurt
# 5    12 oz. portobello mushrooms about 1 large cap ...
# 6                                        brushed clean
# 7                                  and stalks cut away
# 8                                      2 tsp olive oil
# 9                                      salt and pepper
# Name: ingredients, dtype: object

# %%
first_10_matches(r"[0-9]/?[0-9]?")
# Out:
# 0                                          3 large eggs
# 1                       1/3 cup shredded cheddar cheese
# 2                                 1/2 tsp Dijon mustard
# 3                          2 drops Worcestershire sauce
# 4                                   1 tbsp Greek yogurt
# 5     12 oz. portobello mushrooms about 1 large cap ...
# 8                                       2 tsp olive oil
# 11                               1/2 cup cottage cheese
# 12                                   1 tbsp green pesto
# 13      1 tbsp finely chopped sun-dried tomatoes in oil
# Name: ingredients, dtype: object

# %%
ingredients.head(10)
# Out:
#                           recipe_name  \
# 0  Mushroom Rarebit with Poached Eggs
# 1  Mushroom Rarebit with Poached Eggs
# 2  Mushroom Rarebit with Poached Eggs
# 3  Mushroom Rarebit with Poached Eggs
# 4  Mushroom Rarebit with Poached Eggs
# 5  Mushroom Rarebit with Poached Eggs
# 6  Mushroom Rarebit with Poached Eggs
# 7  Mushroom Rarebit with Poached Eggs
# 8  Mushroom Rarebit with Poached Eggs
# 9  Mushroom Rarebit with Poached Eggs
#
#                                          ingredients
# 0                                       3 large eggs
# 1                    1/3 cup shredded cheddar cheese
# 2                              1/2 tsp Dijon mustard
# 3                       2 drops Worcestershire sauce
# 4                                1 tbsp Greek yogurt
# 5  12 oz. portobello mushrooms about 1 large cap ...
# 6                                      brushed clean
# 7                                and stalks cut away
# 8                                    2 tsp olive oil
# 9                                    salt and pepper

# %%
# ingredients['ingredients'].str.extract(r"([0-9]/?[0-9]?)",flags=re.I)
# ingredients['ingredients'].str.extract(r"([\s]?oz.?|tsp?|tbsp?|pinch?|cups?|cup?|lb?|lbs?|drops?)",flags=re.I)
# ingredient_measure = ingredients['ingredients'].str.contains(r"[0-9]/?[0-9]?[\s]?oz.?|tsp?|tbsp?|pinch?|cups?|cup?|lb?|lbs?|drops?",flags=re.I)
# ingredient_measure.sum()
# len(ingredients['ingredients'])

# %%
pattern = r"(?P<measure>[0-9]/?[0-9]?[\s]?oz.?|tsp?|tbsp?|pinch?|cups?|cup?|lb?|lbs?|drops?)\s(?P<name>.+)"
ingredients_v2 = ingredients['ingredients'].str.extract(pattern,flags=re.I)
ingredients_v2
# not capturing fractions with '/' e.g. '1/3 cup'
# also not capturing amounts (digits) without a measure/unit e.g. '3 large eggs'

# %%
pattern = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?oz.?|tsp?|tbsp?|pinch?|cups?|cup?|lb?|lbs?|drops?)\s(?P<name>.+)"
ingredients_v3 = ingredients['ingredients'].str.extractall(pattern,flags=re.I)
ingredients_v3

# %%
ingredients_v2.isnull().sum()
ingredients_v3.isnull().sum()
ingredients_v3['measure'].value_counts()

# %%
pattern = r"(?P<measure>[0-9]/?[0-9]?[\s]?oz.?|tsp?|tbsp?|pinch?|cups?|cup?|lb?|lbs?|drops?)\s(?P<name>.+)"
ingredients_extracted = ingredients['ingredients'].str.extract(pattern,flags=re.I)
ingredients_extracted
# Out:
#       measure                     name
# 0         NaN                      NaN
# 1         cup  shredded cheddar cheese
# 2         tsp            Dijon mustard
# 3       drops     Worcestershire sauce
# 4        tbsp             Greek yogurt
# ...       ...                      ...
# 18428     cup               sour cream
# 18429     cup               mayonnaise
# 18430     cup             ajvar relish
# 18431     NaN                      NaN
# 18432     NaN                      NaN
#
# [18433 rows x 2 columns]

# %%
pattern = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?oz.?|tsp?|tbsp?|pinch?|cups?|cup?|lb?|lbs?|drops?)\s(?P<name>.+)"
ingredients_extracted_v2 = ingredients['ingredients'].str.extractall(pattern,flags=re.I)
ingredients_extracted_v2
# Out:
#             amount measure                                               name
#       match
# 5     0         12     oz.  portobello mushrooms about 1 large cap per ser...
# 16    0        1/2     oz.                                           cucumber
# 18    0          4     oz.                     deli turkey or smoked deli ham
# 23    0          5     oz.                                           zucchini
# 25    0        1/2     oz.                                      celery stalks
# ...            ...     ...                                                ...
# 18402 0          2     oz.                                  fresh raspberries
# 18408 0        1/2     oz.                                             butter
# 18412 0          7     oz.                                      fresh spinach
# 18416 0          6     oz.                                        goat cheese
# 18424 0         14     oz.                                    halloumi cheese
#
# [1886 rows x 3 columns]

# %%
pattern = r"(?P<name>.+)"
ingredients_extracted_v3 = ingredients['ingredients'].str.extract(pattern,flags=re.I)
ingredients_extracted_v3
# Out:
#                                   name
# 0                         3 large eggs
# 1      1/3 cup shredded cheddar cheese
# 2                1/2 tsp Dijon mustard
# 3         2 drops Worcestershire sauce
# 4                  1 tbsp Greek yogurt
# ...                                ...
# 18428               1/4 cup sour cream
# 18429               1/4 cup mayonnaise
# 18430             1/4 cup ajvar relish
# 18431                      poppy seeds
# 18432                         sea salt
#
# [18433 rows x 1 columns]

# %%
ingredients_extracted_v3.isnull().sum()
# Out:
# name    0
# dtype: int64

# %%
pattern_oz = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?oz.?)\s(?P<name>.+)"
ingredients_extracted_oz = ingredients['ingredients'].str.extractall(pattern,flags=re.I)
ingredients_extracted_oz
# Out:
#             amount measure                                               name
#       match
# 5     0         12     oz.  portobello mushrooms about 1 large cap per ser...
# 16    0        1/2     oz.                                           cucumber
# 18    0          4     oz.                     deli turkey or smoked deli ham
# 23    0          5     oz.                                           zucchini
# 25    0        1/2     oz.                                      celery stalks
# ...            ...     ...                                                ...
# 18402 0          2     oz.                                  fresh raspberries
# 18408 0        1/2     oz.                                             butter
# 18412 0          7     oz.                                      fresh spinach
# 18416 0          6     oz.                                        goat cheese
# 18424 0         14     oz.                                    halloumi cheese
#
# [1886 rows x 3 columns]

# %%
measures = ['oz.', 'tsp', 'tbsp', 'pinch', 'cups', 'cup', 'lb', 'lbs', 'drops']

ingredients_extracted = pd.DataFrame()
for measure in measures:
    pattern = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?{measure}?)\s(?P<name>.+)".format(measure)
    extract_measure = ingredients['ingredients'].str.extractall(pattern,flags=re.I)
    ingredients_extracted = pd.concat([ingredients_extracted, extract_measure])
    
ingredients_extracted
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-916e5860f26c> in <module>
#       3 ingredients_extracted = pd.DataFrame()
#       4 for measure in measures:
# ----> 5     pattern = "(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?{measure}?)\s(?P<name>.+)".format(measure)
#       6     extract_measure = ingredients['ingredients'].str.extractall(pattern,flags=re.I)
#       7     ingredients_extracted = pd.concat([ingredients_extracted, extract_measure])
#
# KeyError: 'measure'

# %%
pattern_oz = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?oz.?)\s(?P<name>.+)"
pattern_tsp = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?tsp?)\s(?P<name>.+)"
pattern_tbsp = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?tbsp?)\s(?P<name>.+)"
pattern_pinch = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?pinch?)\s(?P<name>.+)"
pattern_cups = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?cups?)\s(?P<name>.+)"
pattern_cup = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?cup?)\s(?P<name>.+)"
pattern_lb = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?lb?)\s(?P<name>.+)"
pattern_lbs = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?lbs?)\s(?P<name>.+)"
pattern_drops = r"(?P<amount>[0-9]/?[0-9]?)(?P<measure>[\s]?drops?)\s(?P<name>.+)"

patterns = [pattern_oz, pattern_tsp, pattern_tbsp, pattern_pinch, pattern_cups, 
            pattern_cup, pattern_lb, pattern_lbs, pattern_drops]

ingredients_extracted = pd.DataFrame()
for pattern in patterns:
    extract_measure = ingredients['ingredients'].str.extractall(pattern,flags=re.I)
    ingredients_extracted = pd.concat([ingredients_extracted, extract_measure])
    
ingredients_extracted
# Out:
#             amount measure                                               name
#       match
# 5     0         12     oz.  portobello mushrooms about 1 large cap per ser...
# 16    0        1/2     oz.                                           cucumber
# 18    0          4     oz.                     deli turkey or smoked deli ham
# 23    0          5     oz.                                           zucchini
# 25    0        1/2     oz.                                      celery stalks
# ...            ...     ...                                                ...
# 18386 0          2     lbs                            boneless chicken thighs
# 18422 0          1      lb                                           rutabaga
# 3     0          2   drops                               Worcestershire sauce
# 4055  0         10   drops                        liquid sweetener (optional)
# 4458  0         10   drops                          liquid sweetener (stevia)
#
# [10436 rows x 3 columns]

# %%
ingredients_extracted.isnull().sum()
# Out:
# amount     0
# measure    0
# name       0
# dtype: int64

# %%
ingredients_extracted.columns
# Out:
# Index(['amount', 'measure', 'name'], dtype='object')

# %%
ingredients_extracted.index
# Out:
# MultiIndex([(    5, 0),
#             (   16, 0),
#             (   18, 0),
#             (   23, 0),
#             (   25, 0),
#             (   28, 0),
#             (   29, 0),
#             (   30, 0),
#             (   37, 0),
#             (   39, 0),
#             ...
#             (18300, 0),
#             (18308, 0),
#             (18321, 0),
#             (18332, 0),
#             (18356, 0),
#             (18386, 0),
#             (18422, 0),
#             (    3, 0),
#             ( 4055, 0),
#             ( 4458, 0)],
#            names=[None, 'match'], length=10436)

# %%
ingredients_extracted.reset_index()
# Out:
#        level_0  match amount measure  \
# 0            5      0     12     oz.
# 1           16      0    1/2     oz.
# 2           18      0      4     oz.
# 3           23      0      5     oz.
# 4           25      0    1/2     oz.
# ...        ...    ...    ...     ...
# 10431    18386      0      2     lbs
# 10432    18422      0      1      lb
# 10433        3      0      2   drops
# 10434     4055      0     10   drops
# 10435     4458      0     10   drops
#
#                                                     name
# 0      portobello mushrooms about 1 large cap per ser...
# 1                                               cucumber
# 2                         deli turkey or smoked deli ham
# 3                                               zucchini
# 4                                          celery stalks
# ...                                                  ...
# 10431                            boneless chicken thighs
# 10432                                           rutabaga
# 10433                               Worcestershire sauce
# 10434                        liquid sweetener (optional)
# 10435                          liquid sweetener (stevia)
#
# [10436 rows x 5 columns]

# %%
# find instances where measure is missing
measures = ['oz.', 'tsp', 'tbsp', 'pinch', 'cups', 'cup', 'lb', 'lbs', 'drops']
ingredients_no_measure = []
for ingredient in ingredients['ingredients']:
    if not any(x in ingredient for x in measures):
        ingredients_no_measure.append(ingredient)
#     for measure in measures:
#         if not any(measure):
#             ingredients_no_measure.append(ingredient)
#         break
        
ingredients_no_measure
# Out:
# ['3 large eggs',
#  ' brushed clean',
#  ' and stalks cut away',
#  'salt and pepper',
#  ' for seasoning',
#  'salt or ground black pepper to taste',
#  ' diced',
#  ' diced',
#  ' diced',
#  'salt and ground black pepper',
#  ' shredded',
#  'salt to taste',
#  ' drained',
#  ' finely chopped ',
#  '1/4 lime',
#  ' the juice',
#  'salt to taste',
#  '4 small lettuce leafs',
#  '1 red chili pepper',
#  '1 garlic clove',
#  'pepper',
#  ' to taste',
#  '1 white onion',
#  ' for greasing',
#  ' portobello mushrooms',
#  ' large (preferably 2 per serving)',
#  ' roughly chopped (See tip)',
#  ' or ground beef',
#  ' or ground pork',
#  'salt and pepper',
#  '2 large eggs',
#  ' fresh cilantro',
#  ' or flat-leaf parsley',
#  '1 green chili pepper',
#  ' seeded',
#  ' finely sliced',
#  ' cheddar cheese',
#  ' roughly chopped',
#  'salt and pepper',
#  ' for seasoning',
#  ' frozen',
#  ' or fresh',
#  ' divided',
#  '1 yellow onion',
#  ' finely chopped',
#  ' roughly chopped ',
#  '5 large eggs',
#  ' peeled and cut into strips',
#  '2 garlic cloves',
#  ' crushed',
#  ' 1 per portion',
#  'salt and pepper',
#  ' to taste',
#  '1 garlic clove',
#  ' minced',
#  ' fresh ginger',
#  ' melted',
#  ' cut into florets',
#  ' cut into cubes',
#  ' cut into wedges',
#  '1/2 yellow onion',
#  ' cut into thin wedges',
#  ' for garnish (optional)',
#  '1 large egg',
#  '4 fresh rosemary',
#  '2 red onions',
#  '1 red bell pepper',
#  'salt',
#  '1 lemon',
#  'pepper',
#  ' to taste',
#  '1 red chili pepper',
#  '2 garlic cloves',
#  ' or sausages in links',
#  ' finely chopped',
#  '1 garlic clove',
#  ' crushed',
#  ' or hot water',
#  ' fresh cilantro',
#  ' or fresh parsley',
#  ' or fresh dill',
#  'salt and pepper',
#  ' for seasoning',
#  'salt to taste',
#  ' room temperature',
#  '8 large eggs',
#  ' room temperature',
#  ' softened',
#  ' chopped',
#  ' for the pan',
#  'salt to taste',
#  'pepper to taste',
#  ' drained and cut into small cubes .5 (1.5 cm) ',
#  '1 red bell pepper',
#  ' diced',
#  '1 yellow onion',
#  ' diced',
#  'salt and pepper',
#  '1 avocado mashed',
#  ' finely chopped',
#  ' dairy-free or vegan',
#  'salt and pepper',
#  ' to taste',
#  ' sliced ',
#  ' or frozen',
#  ' shredded',
#  ' boneless fillets',
#  'salt or ground black pepper',
#  '1 red bell pepper',
#  '1 eggplant',
#  '1 yellow onion',
#  '4 garlic cloves (optional)',
#  'coarse salt',
#  '2 large eggs',
#  '2 large eggs',
#  'salt or ground black pepper',
#  ' chopped',
#  ' room temperature',
#  'salt and ground black pepper to taste ',
#  '1 scallion',
#  ' chopped',
#  ' chopped',
#  ' chopped',
#  ' crumbled',
#  '1/2 lime',
#  ' the juice',
#  'salt or ground black pepper to taste',
#  ' boneless fillets',
#  'salt',
#  '1/2 lemon',
#  'ground black pepper',
#  '3 large eggs',
#  'salt and pepper',
#  ' to taste',
#  ' sliced',
#  '2 large eggs',
#  ' chopped',
#  ' chopped',
#  ' chopped',
#  ' divided',
#  '3 large eggs',
#  '2 slices Canadian bacon',
#  'salt and pepper',
#  ' to taste',
#  '1/2 apple',
#  'salt',
#  'ground black pepper',
#  ' boneless fillets',
#  '1/2 avocado',
#  '8 turkey hot dogs',
#  '2 avocados',
#  'salt',
#  'pepper',
#  '2 pickled jalapeu00f1os',
#  '4 large eggs',
#  '2 egg yolks',
#  'salt',
#  'pepper',
#  'salt',
#  'ground black pepper',
#  '1 garlic clove',
#  'pepper',
#  'salt',
#  'pepper',
#  '2 large eggs',
#  ' crumbled',
#  ' halved',
#  'salt and ground black pepper',
#  'salt',
#  'pepper',
#  'pepper',
#  '1 egg yolk',
#  '1 yellow onion',
#  '3 large eggs',
#  ' boneless fillets',
#  'salt',
#  'pepper',
#  '3 garlic cloves',
#  '1 large egg',
#  '1 whole sea bass',
#  'salt',
#  '3 garlic cloves',
#  'ground black pepper',
#  '3 large eggs',
#  '5 fresh strawberries (optional)',
#  ' sliced',
#  'ground cinnamon (optional)',
#  'salt',
#  '1 garlic clove',
#  '3 egg yolks',
#  'fresh thyme',
#  'pepper to taste',
#  '4 eggs',
#  '3 eggs',
#  '1 yellow onion',
#  '1 green bell pepper',
#  '1 red bell pepper',
#  '1 egg yolk',
#  '1 yellow onion thinly sliced',
#  '6 eggs beaten',
#  'salt and ground black pepper',
#  ' for seasoning',
#  ' softened',
#  ' softened',
#  ' ground',
#  '2 garlic cloves',
#  '3 large eggs',
#  '2 large eggs',
#  ' crunchy with salt',
#  '4 large eggs',
#  ' sliced or ham',
#  ' cured',
#  '8 large eggs',
#  ' room temperature',
#  ' fresh chives',
#  '4 garlic cloves',
#  '1 avocado',
#  'salt',
#  'ground black pepper',
#  ' to taste',
#  ' thick stems removed or baby spinach',
#  '1 avocado',
#  ' sliced',
#  ' fresh dill',
#  ' fresh chives (optional)',
#  '3 garlic cloves',
#  ' boneless fillets',
#  '1 red chili pepper',
#  ' finely chopped',
#  '2 garlic cloves',
#  ' sliced',
#  ' halved',
#  ' cut into small florets',
#  '2 tomatoes',
#  ' for serving',
#  'salt and ground black pepper',
#  ' bone-in with skin',
#  'salt and ground black pepper to taste',
#  ' sliced',
#  ' chopped',
#  '1 sprig fresh rosemary',
#  ' finely chopped',
#  '2 egg yolks',
#  ' divided',
#  ' sliced ',
#  '2 garlic cloves',
#  ' finely chopped',
#  ' fresh ginger',
#  '1 lime',
#  ' the juice',
#  ' fresh cilantro',
#  ' peeled',
#  ' deveined',
#  ' tail on',
#  'ground black pepper and salt',
#  'salt',
#  '4 lamb chops',
#  'salt and ground black pepper',
#  ' for frying',
#  '2 garlic cloves',
#  ' finely chopped',
#  ' crumbled',
#  ' chopped',
#  ' boneless fillets',
#  ' cut i 1x1 (2',
#  '5 cm)',
#  'salt and ground black pepper',
#  ' spiralized',
#  '1 egg',
#  ' cut in half',
#  'salt and ground black pepper',
#  '2 large eggs',
#  '4 butterhead lettuce leaves',
#  '1/2 tomato',
#  ' sliced',
#  ' canned full fat',
#  '1 lime',
#  ' halved',
#  'salt and pepper',
#  ' to taste',
#  '1 garlic clove',
#  ' coarsely chopped',
#  ' halved',
#  ' skinless fillets ',
#  ' diced',
#  ' chopped',
#  ' puru00e9e',
#  'salt and ground black pepper',
#  ' sliced into strips',
#  '1 sliced red bell pepper',
#  '1 yellow onion',
#  ' sliced',
#  '2 garlic cloves minced',
#  ' for garnish',
#  ' trimmed ',
#  '8 bacon strips (turkey or pork)',
#  'ground black pepper',
#  ' trimmed ',
#  '8 bacon strips (turkey or pork)',
#  ' trimmed and cut into medallions 0.75 (2 cm) thick',
#  '2 garlic cloves',
#  ' crushed',
#  'salt or ground black pepper',
#  ' to taste',
#  ' for greasing (optional)',
#  '2 large eggs',
#  '2 garlic cloves',
#  ' minced',
#  ' sliced',
#  ' trimmed and shredded',
#  ' at room temperature (see tip)',
#  ' divided',
#  '1 garlic clove',
#  '4 garlic cloves',
#  'pepper',
#  '1 lemon',
#  '8 cherry tomatoes',
#  '2 very ripe bananas',
#  ' cut in smaller pieces',
#  '6 large eggs',
#  '1 cinnamon stick',
#  '1 + <span class=ingredient-optional>1 (optional)</span> lemon',
#  '1 garlic clove',
#  'pepper',
#  '4 large eggs',
#  ' ground',
#  '3 garlic cloves',
#  '2 red onions',
#  '1 habanero pepper',
#  '4 large eggs',
#  '1/2 iceberg lettuce',
#  '1 tomato',
#  '4 large eggs',
#  '1 garlic clove',
#  'salt',
#  'ground black pepper',
#  '8 butterhead lettuce',
#  '4 cheddar cheese',
#  '1/2 yellow onion',
#  '1 tomato',
#  ' shelled and deveined',
#  '1 cucumber',
#  '1/2 red onion',
#  ' cut into strips',
#  '1 fresh jalapeu00f1o',
#  ' deseeded',
#  '1 ripe avocado',
#  ' cut into florets',
#  ' room temperature',
#  ' room temperature',
#  'salt and ground black pepper',
#  ' to taste',
#  ' chopped',
#  ' thinly sliced',
#  'salt',
#  'ground black pepper',
#  ' for seasoning',
#  '2 garlic cloves',
#  ' cut into strips',
#  '1 tomato',
#  ' cut in half and sliced',
#  'salt',
#  ' to taste',
#  '1 avocado',
#  '1 garlic clove',
#  'salt',
#  'ground black pepper',
#  '4 boneless chicken thighs',
#  '2 red bell peppers',
#  ' cooked and cut into small pieces',
#  'salt and ground black pepper',
#  ' to taste',
#  '1 scallion',
#  ' finely sliced',
#  '4 leaves butterhead lettuce',
#  '2 avocados',
#  ' halved lengthwise',
#  ' pit removed (see tip)',
#  ' drained',
#  '1 celery stalk',
#  ' finely chopped',
#  ' finely chopped',
#  'salt and ground black pepper',
#  ' to taste',
#  ' finely chopped (optional)',
#  '3 garlic cloves',
#  'salt',
#  '4 large eggs',
#  '2 limes (optional)',
#  '4 eggs',
#  ' boneless fillets',
#  '1 garlic clove',
#  '1 1/2 limes',
#  '1/2 red chili pepper',
#  'salt',
#  'ground black pepper',
#  '1/2 cucumber',
#  '2 avocados',
#  '1/2 yellow onion',
#  '2 garlic cloves',
#  '1 tomato',
#  '4 fresh jalapeu00f1os',
#  'salt',
#  'ground black pepper',
#  '1 avocado',
#  '1 egg white',
#  '2 eggs',
#  ' one separated',
#  ' shredded',
#  ' softened',
#  '6 un-cooked sausages in links',
#  ' softened',
#  ' chopped or shaved ',
#  '6 garlic cloves',
#  '2 lemons',
#  '1 yellow onion',
#  '4 tomatoes',
#  '4 skewers (metal or wooden)',
#  ' boneless fillets',
#  '1 orange',
#  '1 + <span class=ingredient-optional>1 (optional)</span> orange',
#  '2 garlic cloves',
#  ' divided',
#  ' finely chopped ',
#  '1 egg',
#  '1 2/3 red onions',
#  '1 egg',
#  '2 chipotle chili peppers',
#  '1 orange',
#  '2 red onions',
#  '5 bay leaves',
#  '1/2 meat bouillon cube (optional)',
#  '6 large eggs',
#  '1 orange',
#  '1 red onion',
#  '1 shallot',
#  '15 dried juniper berries',
#  '1 large egg',
#  '4 eggs',
#  '5 fresh rosemary',
#  ' thinly sliced',
#  ' thinly sliced',
#  '1 boiled large egg',
#  ' cut in half',
#  'salt and pepper to taste',
#  ' diced finely',
#  ' quartered',
#  ' cubed',
#  'salt',
#  ' to taste',
#  ' peeled and chopped',
#  '1 lemon',
#  '4 large eggs',
#  'ghee',
#  '6 eggs',
#  '12 fresh strawberries',
#  ' chopped',
#  '1/2 red onion',
#  ' sliced',
#  ' roasted and salted',
#  ' crushed ',
#  ' melted',
#  '2 garlic cloves',
#  ' for frying',
#  '1 + <span class=ingredient-optional>1 (optional)</span> lemon',
#  '5 garlic cloves',
#  'salt',
#  'pepper',
#  '1 yellow onion',
#  '1 green bell pepper',
#  '2 tomatoes',
#  'fresh thyme (optional)',
#  '1 egg',
#  '1 lemon (optional)',
#  '4 large eggs',
#  '2 lemons',
#  '1 egg',
#  '1 nori sheet',
#  '1 radish',
#  '4 dill pickles',
#  '6 eggs',
#  'butter',
#  ' shredded',
#  '8 large eggs',
#  ' or tomato paste (thinned with water)',
#  '4 black olives',
#  ' halved',
#  'salt & pepper',
#  ' to taste',
#  '1 yellow onion',
#  '1 garlic clove',
#  '1 vegetable bouillon cube (optional)',
#  'salt',
#  'pepper',
#  ' to taste',
#  ' mini cheese balls',
#  ' sliced',
#  '6 large eggs',
#  ' boiled',
#  '18 black olives',
#  ' unpeeled',
#  ' and shredded',
#  '2 large eggs',
#  '2 garlic cloves',
#  '1 large egg',
#  '2 tomatoes',
#  '1/2 red onion',
#  '4 pickles',
#  '2 eggs',
#  ' shredded',
#  '6 eggs',
#  'poppy seeds',
#  ' for topping',
#  ' boneless fillets',
#  ' chopped',
#  '1 red onion',
#  ' thinly sliced',
#  '1 large egg',
#  ' boiled',
#  ' sliced',
#  '2 cherry tomatoes',
#  ' sliced in half',
#  ' crumbled',
#  ' thinly sliced',
#  'Salt and pepper',
#  ' to taste',
#  '1 egg',
#  '6 egg yolks',
#  '5 eggs',
#  '1 large egg',
#  '1/2 tomato',
#  'salt',
#  'pepper to taste',
#  '2 eggs',
#  ' boneless fillets',
#  '1 red onion',
#  '8 cherry tomatoes',
#  '1 lime',
#  '2 avocados',
#  '2 garlic cloves',
#  '1/2 red chili pepper (optional)',
#  'salt',
#  'ground black pepper',
#  '1 lime (optional)',
#  '3 garlic cloves',
#  'salt',
#  '1 lime (optional)',
#  'pepper to taste',
#  ' divided',
#  ' yellow onions',
#  ' halved lengthwise and sliced across',
#  ' fresh ginger',
#  ' softened',
#  '1 egg yolk',
#  '18 hazelnuts',
#  ' softened',
#  '1 large egg',
#  'salt',
#  'pepper',
#  '1 lime',
#  ' diced',
#  ' diced',
#  '2 garlic cloves',
#  ' finely chopped',
#  '1 green bell pepper',
#  ' cut into chunks',
#  'Salt ground black pepper',
#  ' to taste',
#  'fresh parsley',
#  ' for garnishing (optional)',
#  ' sliced ',
#  ' sliced thinly',
#  'salt and pepper to taste',
#  ' cut in wedges',
#  ' sliced',
#  'salt and pepper to taste',
#  '1 medium unripe banana',
#  '2 large eggs',
#  ' spiralized',
#  '4 garlic cloves',
#  ' finely chopped',
#  ' cut into bite-sized pieces',
#  '1 lemon',
#  ' juice and zest',
#  ' finely grated',
#  ' cut into bite sized pieces',
#  '3 garlic cloves',
#  ' finely chopped',
#  '1 red chili pepper',
#  ' finely chopped',
#  ' boneless fillets',
#  ' cut into 1 (2.5 cm) cubes',
#  'salt and ground black pepper',
#  ' to taste',
#  ' opened',
#  'Drippings from the chicken',
#  '1/2 lemon',
#  '3 tomatoes',
#  '4 garlic cloves',
#  '4 bay leaves',
#  'pepper',
#  '1 1/2 lemons',
#  '6 garlic cloves',
#  '1 large egg',
#  ' optional',
#  '1 egg',
#  '4 tomatoes',
#  '3 eggs',
#  'salt',
#  '2 tomatoes',
#  ' for greasing',
#  '8 eggs',
#  ' cut into florets',
#  ' skinless boneless chicken thighs',
#  ' cut into 1 (3 cm) pieces',
#  ' spiralized',
#  ' diced',
#  ' or cherry tomatoes cut in half',
#  'salt and ground black pepper',
#  ' to taste',
#  '1/2 avocado',
#  '1/2 red chili pepper',
#  '4 eggs',
#  '4 large eggs',
#  ' drained',
#  ' diced',
#  ' or ready made zucchini noodles',
#  'ground black pepper and salt',
#  ' to taste',
#  '1 yellow onion',
#  '2 garlic cloves',
#  'pepper',
#  'salt',
#  'ground black pepper',
#  '8 eggs',
#  '2 large eggs',
#  '2 tomatoes',
#  '2 garlic cloves',
#  '10 eggs',
#  'salt',
#  'ground black pepper',
#  ' to taste',
#  '6 large eggs',
#  'unsalted butter',
#  '6 large eggs yolks',
#  '1 egg',
#  '3 garlic cloves',
#  'pepper to taste',
#  '5 eggs',
#  '4 celery stalks',
#  '4 garlic cloves',
#  '4 bay leaves',
#  '4 fresh rosemary',
#  '4 fresh thyme',
#  'salt',
#  'sea salt',
#  '4 red bell peppers',
#  '3 garlic cloves',
#  '4 egg yolks',
#  '1 large egg',
#  ' boneless fillets',
#  '6 garlic cloves',
#  '1 + <span class=ingredient-optional>4 (optional)</span> lemon',
#  '1 red chili pepper',
#  'salt',
#  'olive oil',
#  'ground black pepper',
#  '1 garlic clove',
#  'pepper',
#  '1 yellow onion',
#  '1 red bell pepper',
#  '4 eggs',
#  ' divided',
#  '2 garlic cloves',
#  ' finely chopped',
#  ' mixed',
#  ' peeled and deveined',
#  '1 red bell pepper',
#  ' thinly sliced',
#  ' sliced length-wise',
#  ' into quarters',
#  ' sliced thinly',
#  ' length-wise',
#  'chili flakes and finely sliced scallion',
#  ' to garnish (optional)',
#  '1 garlic clove',
#  'salt',
#  'pepper to taste',
#  'drippings from the meat',
#  'salt',
#  'pepper to taste',
#  '2 lemons',
#  ' canned',
#  ' canned',
#  ' allulose or xylitol',
#  ' sifted',
#  ' espresso (optional)',
#  'for serving ice cube',
#  '1 egg yolk',
#  '3 carrots',
#  '2 yellow onions',
#  '4 bay leaves',
#  '12 peppercorns',
#  ' white',
#  'salt',
#  'pepper to taste',
#  '3 garlic cloves',
#  '2 oranges',
#  ' boneless fillets',
#  '1 egg',
#  'sea salt',
#  '1/2 yellow onion',
#  ' chopped',
#  '1 garlic clove',
#  ' crushed',
#  '1 fresh jalapeu00f1o',
#  ' chopped',
#  '2 tomatoes',
#  ' chopped',
#  ' cut into small cubes',
#  '2 poblano peppers',
#  ' roasted and cut into strips',
#  ' or boiled water',
#  '1 white onion',
#  ' chopped',
#  ' chopped',
#  ' cubed',
#  ' grated',
#  ' chopped (optional)',
#  '1 avocado',
#  '1 lime (optional)',
#  '12 green asparagus spears',
#  ' cured',
#  ' sliced',
#  ' sliced',
#  'salt and pepper to taste',
#  '5 eggs',
#  '4 large pickles',
#  '1 tomato',
#  ' sliced ',
#  '2 lettuce leafs',
#  '1/4 red onion',
#  ' sliced ',
#  'salt and ground black pepper',
#  '4 tooth picks',
#  '4 chicken breasts',
#  ' bone-in with skin',
#  '2 garlic cloves',
#  '1 Romaine lettuce',
#  '12 cherry tomatoes',
#  '1/2 red onion',
#  'salt and pepper',
#  ' to taste',
#  ' cut into slices ',
#  '1 red onion',
#  ' sliced thinly',
#  ' sliced thinly',
#  ' for greasing pan',
#  '1 garlic clove',
#  'pepper',
#  ' mini cheese balls',
#  '2 garlic cloves',
#  '1/2 lemon',
#  '  finely chopped',
#  '2 garlic cloves',
#  ' minced ',
#  '  finely chopped',
#  '4 skewers (metal or wooden)',
#  ' white',
#  '1 lemon',
#  'salt',
#  'ground black pepper',
#  '1 yellow bell pepper',
#  'salt',
#  'pepper to taste',
#  '1 garlic clove',
#  'ground black pepper',
#  '1 eggplant',
#  '2 tomatoes',
#  ' halved ',
#  ' crumbled or cubed',
#  '1/2 red onion',
#  '2 tomatoes',
#  '3 egg whites',
#  '4 eggs',
#  '3 egg yolks',
#  ' chopped',
#  '1 lemon',
#  ' zest and juice',
#  ' grated',
#  ' for decoration',
#  '3 avocados',
#  ' cut into eights ',
#  ' sliced ',
#  ' sliced ',
#  ' quartered',
#  ' diced ',
#  'salt and pepper  to taste',
#  '1 red onion',
#  ' fillets',
#  '8 eggs',
#  ' fried and chopped into small bits',
#  ' thinly sliced',
#  '1 lemon',
#  '6 garlic cloves',
#  '6 scallions',
#  '2 red chili peppers',
#  '3 egg whites',
#  ' tenderloin',
#  '1 garlic clove',
#  'pepper',
#  '1 egg',
#  '1 avocado',
#  '1/2 lime',
#  '1/2 red onion',
#  '1/2 red bell pepper',
#  '1 fresh jalapeu00f1o',
#  ' cut into florets',
#  '1 egg',
#  ' or fennel seeds.',
#  ' casings removed',
#  '3 garlic cloves',
#  ' crushed',
#  '1 red onion',
#  ' diced',
#  '1 red bell pepper',
#  ' cut into strips',
#  '1 green bell pepper',
#  ' cut into strips',
#  '1 tomato',
#  ' diced',
#  '1 lime',
#  ' juice',
#  ' or to taste',
#  ' or to taste',
#  ' leaves',
#  ' finely chopped',
#  '2 shallots',
#  ' finely chopped',
#  '1 egg',
#  'salt and ground black pepper to taste',
#  ' cut into pieces',
#  '1/2 lime',
#  ' the juice',
#  '3 garlic cloves',
#  ' crushed',
#  '1/2 red bell pepper',
#  ' minced',
#  '2 celery stalks',
#  ' minced',
#  ' pitted',
#  ' minced',
#  ' spiralized',
#  ' peeled and chopped',
#  ' peeled and chopped',
#  '1/2 red onion',
#  ' chopped',
#  '2 garlic cloves',
#  ' crushed',
#  ' chopped',
#  ' minced',
#  '2 limes  for serving',
#  ' or to taste (optional)',
#  ' boneless fillets',
#  'salt',
#  '8 cherry tomatoes',
#  '1/2 Romaine lettuce',
#  '1/4 red onion',
#  '1/2 + <span class=ingredient-optional>1/2 (optional)</span> lemon',
#  'ground black pepper',
#  '1 avocado',
#  '1 garlic clove',
#  'pepper to taste ',
#  '1 large yellow onion sliced into u00bcu201d rounds (vidalia',
#  ' white or red)',
#  '2 eggs',
#  " refined if you don't love the coconut flavor ",
#  'salt to taste',
#  ' sliced',
#  '1 red bell pepper',
#  ' thinly sliced',
#  '2 garlic cloves',
#  ' finely chopped ',
#  ' roughly chopped ',
#  '8 eggs',
#  'salt',
#  'pepper',
#  '8 bacon',
#  '8 cherry tomatoes',
#  ' tenderloin',
#  '1/2 yellow onion',
#  ' grated',
#  '2 eggs',
#  ' diced',
#  ' finely chopped',
#  'coarse salt',
#  'ground black pepper',
#  '4 eggs',
#  '2 limes',
#  '1 red chili pepper',
#  ' boneless fillets',
#  'salt (optional)',
#  '2 scallions',
#  '1 cucumber',
#  '1 carrot',
#  '1 avocado',
#  '1 garlic clove',
#  '4 eggs',
#  '4 eggs',
#  '1 1/2 scallions',
#  '2 fresh jalapeu00f1os',
#  ' casings removed',
#  ' cured',
#  ' cubed or sliced',
#  ' chopped and cooked',
#  ' shredded',
#  '6 large eggs',
#  '2 large eggs',
#  'salt and ground black pepper',
#  '1 white onion',
#  '3 garlic cloves',
#  '1 bay leaf',
#  '3 tomatoes',
#  '20 shrimp',
#  '16 fresh mussels',
#  '8 scallops',
#  '1/2 lime',
#  '1 egg',
#  '1/2 lemon',
#  '4 eggs',
#  '2 garlic cloves',
#  ' minced ',
#  ' sliced ',
#  '1/2 lemon',
#  ' juice and zest',
#  ' boneless fillets or other firm fish',
#  ' pin bones removed',
#  ' fillets cut into 1 pieces',
#  'salt and ground black pepper',
#  'fresh sage',
#  ' optional for garnish',
#  ' sliced',
#  '3 eggs',
#  ' diced ',
#  'salt and ground black pepper',
#  ' shredded ',
#  '1/2 scallion',
#  ' chopped ',
#  '4 eggs',
#  '4 eggs',
#  '16 pepperoni',
#  '2 eggs',
#  ' cubed ',
#  '1/2 tomato',
#  'salt and ground black pepper',
#  '4 tomatoes',
#  ' chopped',
#  '1/4 yellow onion',
#  ' chopped',
#  '1 garlic clove',
#  ' chopped',
#  '3 chipotle chili peppers',
#  '4 leaves Romaine lettuce',
#  '2 avocados',
#  ' cut into cubes',
#  '1 egg',
#  '3 egg yolks',
#  'salt',
#  'pepper to taste ',
#  '2 avocados',
#  '4 large eggs',
#  '3 eggs',
#  'unsalted butter',
#  '1 bottle (750 ml) sparkling wine (dry) with or without alcohol or sparkling water',
#  ' unsweetened',
#  ' unsweetened',
#  '6 sprigs fresh rosemary',
#  '4 eggs',
#  '2 garlic cloves',
#  'salt',
#  'ground black pepper',
#  '2 garlic cloves',
#  '3 eggs',
#  '1/4 red onion',
#  '1 garlic clove',
#  '1/4 red bell pepper',
#  '1 zucchini',
#  '1 fresh jalapeu00f1o',
#  ' boneless fillets',
#  '1 yellow onion',
#  '3 garlic cloves',
#  '1 egg',
#  'ground black pepper',
#  'pepper',
#  '8 cherry tomatoes',
#  '1 red onion',
#  '1/2 lemon',
#  '1/2 pomegranate',
#  'sea salt',
#  'ground black pepper',
#  ...]

# %%
# list contains some non-ingredients that were the result of the split on comma, which appear to have a leading space
# let's remove any ingredients with a leading space
ingredients_no_measure_clean = []
for ingredient in ingredients_no_measure:
    if not ingredient.startswith(' '):
        ingredients_no_measure_clean.append(ingredient)
        
ingredients_no_measure_clean
# Out:
# ['3 large eggs',
#  'salt and pepper',
#  'salt or ground black pepper to taste',
#  'salt and ground black pepper',
#  'salt to taste',
#  '1/4 lime',
#  'salt to taste',
#  '4 small lettuce leafs',
#  '1 red chili pepper',
#  '1 garlic clove',
#  'pepper',
#  '1 white onion',
#  'salt and pepper',
#  '2 large eggs',
#  '1 green chili pepper',
#  'salt and pepper',
#  '1 yellow onion',
#  '5 large eggs',
#  '2 garlic cloves',
#  'salt and pepper',
#  '1 garlic clove',
#  '1/2 yellow onion',
#  '1 large egg',
#  '4 fresh rosemary',
#  '2 red onions',
#  '1 red bell pepper',
#  'salt',
#  '1 lemon',
#  'pepper',
#  '1 red chili pepper',
#  '2 garlic cloves',
#  '1 garlic clove',
#  'salt and pepper',
#  'salt to taste',
#  '8 large eggs',
#  'salt to taste',
#  'pepper to taste',
#  '1 red bell pepper',
#  '1 yellow onion',
#  'salt and pepper',
#  '1 avocado mashed',
#  'salt and pepper',
#  'salt or ground black pepper',
#  '1 red bell pepper',
#  '1 eggplant',
#  '1 yellow onion',
#  '4 garlic cloves (optional)',
#  'coarse salt',
#  '2 large eggs',
#  '2 large eggs',
#  'salt or ground black pepper',
#  'salt and ground black pepper to taste ',
#  '1 scallion',
#  '1/2 lime',
#  'salt or ground black pepper to taste',
#  'salt',
#  '1/2 lemon',
#  'ground black pepper',
#  '3 large eggs',
#  'salt and pepper',
#  '2 large eggs',
#  '3 large eggs',
#  '2 slices Canadian bacon',
#  'salt and pepper',
#  '1/2 apple',
#  'salt',
#  'ground black pepper',
#  '1/2 avocado',
#  '8 turkey hot dogs',
#  '2 avocados',
#  'salt',
#  'pepper',
#  '2 pickled jalapeu00f1os',
#  '4 large eggs',
#  '2 egg yolks',
#  'salt',
#  'pepper',
#  'salt',
#  'ground black pepper',
#  '1 garlic clove',
#  'pepper',
#  'salt',
#  'pepper',
#  '2 large eggs',
#  'salt and ground black pepper',
#  'salt',
#  'pepper',
#  'pepper',
#  '1 egg yolk',
#  '1 yellow onion',
#  '3 large eggs',
#  'salt',
#  'pepper',
#  '3 garlic cloves',
#  '1 large egg',
#  '1 whole sea bass',
#  'salt',
#  '3 garlic cloves',
#  'ground black pepper',
#  '3 large eggs',
#  '5 fresh strawberries (optional)',
#  'ground cinnamon (optional)',
#  'salt',
#  '1 garlic clove',
#  '3 egg yolks',
#  'fresh thyme',
#  'pepper to taste',
#  '4 eggs',
#  '3 eggs',
#  '1 yellow onion',
#  '1 green bell pepper',
#  '1 red bell pepper',
#  '1 egg yolk',
#  '1 yellow onion thinly sliced',
#  '6 eggs beaten',
#  'salt and ground black pepper',
#  '2 garlic cloves',
#  '3 large eggs',
#  '2 large eggs',
#  '4 large eggs',
#  '8 large eggs',
#  '4 garlic cloves',
#  '1 avocado',
#  'salt',
#  'ground black pepper',
#  '1 avocado',
#  '3 garlic cloves',
#  '1 red chili pepper',
#  '2 garlic cloves',
#  '2 tomatoes',
#  'salt and ground black pepper',
#  'salt and ground black pepper to taste',
#  '1 sprig fresh rosemary',
#  '2 egg yolks',
#  '2 garlic cloves',
#  '1 lime',
#  'ground black pepper and salt',
#  'salt',
#  '4 lamb chops',
#  'salt and ground black pepper',
#  '2 garlic cloves',
#  '5 cm)',
#  'salt and ground black pepper',
#  '1 egg',
#  'salt and ground black pepper',
#  '2 large eggs',
#  '4 butterhead lettuce leaves',
#  '1/2 tomato',
#  '1 lime',
#  'salt and pepper',
#  '1 garlic clove',
#  'salt and ground black pepper',
#  '1 sliced red bell pepper',
#  '1 yellow onion',
#  '2 garlic cloves minced',
#  '8 bacon strips (turkey or pork)',
#  'ground black pepper',
#  '8 bacon strips (turkey or pork)',
#  '2 garlic cloves',
#  'salt or ground black pepper',
#  '2 large eggs',
#  '2 garlic cloves',
#  '1 garlic clove',
#  '4 garlic cloves',
#  'pepper',
#  '1 lemon',
#  '8 cherry tomatoes',
#  '2 very ripe bananas',
#  '6 large eggs',
#  '1 cinnamon stick',
#  '1 + <span class=ingredient-optional>1 (optional)</span> lemon',
#  '1 garlic clove',
#  'pepper',
#  '4 large eggs',
#  '3 garlic cloves',
#  '2 red onions',
#  '1 habanero pepper',
#  '4 large eggs',
#  '1/2 iceberg lettuce',
#  '1 tomato',
#  '4 large eggs',
#  '1 garlic clove',
#  'salt',
#  'ground black pepper',
#  '8 butterhead lettuce',
#  '4 cheddar cheese',
#  '1/2 yellow onion',
#  '1 tomato',
#  '1 cucumber',
#  '1/2 red onion',
#  '1 fresh jalapeu00f1o',
#  '1 ripe avocado',
#  'salt and ground black pepper',
#  'salt',
#  'ground black pepper',
#  '2 garlic cloves',
#  '1 tomato',
#  'salt',
#  '1 avocado',
#  '1 garlic clove',
#  'salt',
#  'ground black pepper',
#  '4 boneless chicken thighs',
#  '2 red bell peppers',
#  'salt and ground black pepper',
#  '1 scallion',
#  '4 leaves butterhead lettuce',
#  '2 avocados',
#  '1 celery stalk',
#  'salt and ground black pepper',
#  '3 garlic cloves',
#  'salt',
#  '4 large eggs',
#  '2 limes (optional)',
#  '4 eggs',
#  '1 garlic clove',
#  '1 1/2 limes',
#  '1/2 red chili pepper',
#  'salt',
#  'ground black pepper',
#  '1/2 cucumber',
#  '2 avocados',
#  '1/2 yellow onion',
#  '2 garlic cloves',
#  '1 tomato',
#  '4 fresh jalapeu00f1os',
#  'salt',
#  'ground black pepper',
#  '1 avocado',
#  '1 egg white',
#  '2 eggs',
#  '6 un-cooked sausages in links',
#  '6 garlic cloves',
#  '2 lemons',
#  '1 yellow onion',
#  '4 tomatoes',
#  '4 skewers (metal or wooden)',
#  '1 orange',
#  '1 + <span class=ingredient-optional>1 (optional)</span> orange',
#  '2 garlic cloves',
#  '1 egg',
#  '1 2/3 red onions',
#  '1 egg',
#  '2 chipotle chili peppers',
#  '1 orange',
#  '2 red onions',
#  '5 bay leaves',
#  '1/2 meat bouillon cube (optional)',
#  '6 large eggs',
#  '1 orange',
#  '1 red onion',
#  '1 shallot',
#  '15 dried juniper berries',
#  '1 large egg',
#  '4 eggs',
#  '5 fresh rosemary',
#  '1 boiled large egg',
#  'salt and pepper to taste',
#  'salt',
#  '1 lemon',
#  '4 large eggs',
#  'ghee',
#  '6 eggs',
#  '12 fresh strawberries',
#  '1/2 red onion',
#  '2 garlic cloves',
#  '1 + <span class=ingredient-optional>1 (optional)</span> lemon',
#  '5 garlic cloves',
#  'salt',
#  'pepper',
#  '1 yellow onion',
#  '1 green bell pepper',
#  '2 tomatoes',
#  'fresh thyme (optional)',
#  '1 egg',
#  '1 lemon (optional)',
#  '4 large eggs',
#  '2 lemons',
#  '1 egg',
#  '1 nori sheet',
#  '1 radish',
#  '4 dill pickles',
#  '6 eggs',
#  'butter',
#  '8 large eggs',
#  '4 black olives',
#  'salt & pepper',
#  '1 yellow onion',
#  '1 garlic clove',
#  '1 vegetable bouillon cube (optional)',
#  'salt',
#  'pepper',
#  '6 large eggs',
#  '18 black olives',
#  '2 large eggs',
#  '2 garlic cloves',
#  '1 large egg',
#  '2 tomatoes',
#  '1/2 red onion',
#  '4 pickles',
#  '2 eggs',
#  '6 eggs',
#  'poppy seeds',
#  '1 red onion',
#  '1 large egg',
#  '2 cherry tomatoes',
#  'Salt and pepper',
#  '1 egg',
#  '6 egg yolks',
#  '5 eggs',
#  '1 large egg',
#  '1/2 tomato',
#  'salt',
#  'pepper to taste',
#  '2 eggs',
#  '1 red onion',
#  '8 cherry tomatoes',
#  '1 lime',
#  '2 avocados',
#  '2 garlic cloves',
#  '1/2 red chili pepper (optional)',
#  'salt',
#  'ground black pepper',
#  '1 lime (optional)',
#  '3 garlic cloves',
#  'salt',
#  '1 lime (optional)',
#  'pepper to taste',
#  '1 egg yolk',
#  '18 hazelnuts',
#  '1 large egg',
#  'salt',
#  'pepper',
#  '1 lime',
#  '2 garlic cloves',
#  '1 green bell pepper',
#  'Salt ground black pepper',
#  'fresh parsley',
#  'salt and pepper to taste',
#  'salt and pepper to taste',
#  '1 medium unripe banana',
#  '2 large eggs',
#  '4 garlic cloves',
#  '1 lemon',
#  '3 garlic cloves',
#  '1 red chili pepper',
#  'salt and ground black pepper',
#  'Drippings from the chicken',
#  '1/2 lemon',
#  '3 tomatoes',
#  '4 garlic cloves',
#  '4 bay leaves',
#  'pepper',
#  '1 1/2 lemons',
#  '6 garlic cloves',
#  '1 large egg',
#  '1 egg',
#  '4 tomatoes',
#  '3 eggs',
#  'salt',
#  '2 tomatoes',
#  '8 eggs',
#  'salt and ground black pepper',
#  '1/2 avocado',
#  '1/2 red chili pepper',
#  '4 eggs',
#  '4 large eggs',
#  'ground black pepper and salt',
#  '1 yellow onion',
#  '2 garlic cloves',
#  'pepper',
#  'salt',
#  'ground black pepper',
#  '8 eggs',
#  '2 large eggs',
#  '2 tomatoes',
#  '2 garlic cloves',
#  '10 eggs',
#  'salt',
#  'ground black pepper',
#  '6 large eggs',
#  'unsalted butter',
#  '6 large eggs yolks',
#  '1 egg',
#  '3 garlic cloves',
#  'pepper to taste',
#  '5 eggs',
#  '4 celery stalks',
#  '4 garlic cloves',
#  '4 bay leaves',
#  '4 fresh rosemary',
#  '4 fresh thyme',
#  'salt',
#  'sea salt',
#  '4 red bell peppers',
#  '3 garlic cloves',
#  '4 egg yolks',
#  '1 large egg',
#  '6 garlic cloves',
#  '1 + <span class=ingredient-optional>4 (optional)</span> lemon',
#  '1 red chili pepper',
#  'salt',
#  'olive oil',
#  'ground black pepper',
#  '1 garlic clove',
#  'pepper',
#  '1 yellow onion',
#  '1 red bell pepper',
#  '4 eggs',
#  '2 garlic cloves',
#  '1 red bell pepper',
#  'chili flakes and finely sliced scallion',
#  '1 garlic clove',
#  'salt',
#  'pepper to taste',
#  'drippings from the meat',
#  'salt',
#  'pepper to taste',
#  '2 lemons',
#  'for serving ice cube',
#  '1 egg yolk',
#  '3 carrots',
#  '2 yellow onions',
#  '4 bay leaves',
#  '12 peppercorns',
#  'salt',
#  'pepper to taste',
#  '3 garlic cloves',
#  '2 oranges',
#  '1 egg',
#  'sea salt',
#  '1/2 yellow onion',
#  '1 garlic clove',
#  '1 fresh jalapeu00f1o',
#  '2 tomatoes',
#  '2 poblano peppers',
#  '1 white onion',
#  '1 avocado',
#  '1 lime (optional)',
#  '12 green asparagus spears',
#  'salt and pepper to taste',
#  '5 eggs',
#  '4 large pickles',
#  '1 tomato',
#  '2 lettuce leafs',
#  '1/4 red onion',
#  'salt and ground black pepper',
#  '4 tooth picks',
#  '4 chicken breasts',
#  '2 garlic cloves',
#  '1 Romaine lettuce',
#  '12 cherry tomatoes',
#  '1/2 red onion',
#  'salt and pepper',
#  '1 red onion',
#  '1 garlic clove',
#  'pepper',
#  '2 garlic cloves',
#  '1/2 lemon',
#  '2 garlic cloves',
#  '4 skewers (metal or wooden)',
#  '1 lemon',
#  'salt',
#  'ground black pepper',
#  '1 yellow bell pepper',
#  'salt',
#  'pepper to taste',
#  '1 garlic clove',
#  'ground black pepper',
#  '1 eggplant',
#  '2 tomatoes',
#  '1/2 red onion',
#  '2 tomatoes',
#  '3 egg whites',
#  '4 eggs',
#  '3 egg yolks',
#  '1 lemon',
#  '3 avocados',
#  'salt and pepper  to taste',
#  '1 red onion',
#  '8 eggs',
#  '1 lemon',
#  '6 garlic cloves',
#  '6 scallions',
#  '2 red chili peppers',
#  '3 egg whites',
#  '1 garlic clove',
#  'pepper',
#  '1 egg',
#  '1 avocado',
#  '1/2 lime',
#  '1/2 red onion',
#  '1/2 red bell pepper',
#  '1 fresh jalapeu00f1o',
#  '1 egg',
#  '3 garlic cloves',
#  '1 red onion',
#  '1 red bell pepper',
#  '1 green bell pepper',
#  '1 tomato',
#  '1 lime',
#  '2 shallots',
#  '1 egg',
#  'salt and ground black pepper to taste',
#  '1/2 lime',
#  '3 garlic cloves',
#  '1/2 red bell pepper',
#  '2 celery stalks',
#  '1/2 red onion',
#  '2 garlic cloves',
#  '2 limes  for serving',
#  'salt',
#  '8 cherry tomatoes',
#  '1/2 Romaine lettuce',
#  '1/4 red onion',
#  '1/2 + <span class=ingredient-optional>1/2 (optional)</span> lemon',
#  'ground black pepper',
#  '1 avocado',
#  '1 garlic clove',
#  'pepper to taste ',
#  '1 large yellow onion sliced into u00bcu201d rounds (vidalia',
#  '2 eggs',
#  'salt to taste',
#  '1 red bell pepper',
#  '2 garlic cloves',
#  '8 eggs',
#  'salt',
#  'pepper',
#  '8 bacon',
#  '8 cherry tomatoes',
#  '1/2 yellow onion',
#  '2 eggs',
#  'coarse salt',
#  'ground black pepper',
#  '4 eggs',
#  '2 limes',
#  '1 red chili pepper',
#  'salt (optional)',
#  '2 scallions',
#  '1 cucumber',
#  '1 carrot',
#  '1 avocado',
#  '1 garlic clove',
#  '4 eggs',
#  '4 eggs',
#  '1 1/2 scallions',
#  '2 fresh jalapeu00f1os',
#  '6 large eggs',
#  '2 large eggs',
#  'salt and ground black pepper',
#  '1 white onion',
#  '3 garlic cloves',
#  '1 bay leaf',
#  '3 tomatoes',
#  '20 shrimp',
#  '16 fresh mussels',
#  '8 scallops',
#  '1/2 lime',
#  '1 egg',
#  '1/2 lemon',
#  '4 eggs',
#  '2 garlic cloves',
#  '1/2 lemon',
#  'salt and ground black pepper',
#  'fresh sage',
#  '3 eggs',
#  'salt and ground black pepper',
#  '1/2 scallion',
#  '4 eggs',
#  '4 eggs',
#  '16 pepperoni',
#  '2 eggs',
#  '1/2 tomato',
#  'salt and ground black pepper',
#  '4 tomatoes',
#  '1/4 yellow onion',
#  '1 garlic clove',
#  '3 chipotle chili peppers',
#  '4 leaves Romaine lettuce',
#  '2 avocados',
#  '1 egg',
#  '3 egg yolks',
#  'salt',
#  'pepper to taste ',
#  '2 avocados',
#  '4 large eggs',
#  '3 eggs',
#  'unsalted butter',
#  '1 bottle (750 ml) sparkling wine (dry) with or without alcohol or sparkling water',
#  '6 sprigs fresh rosemary',
#  '4 eggs',
#  '2 garlic cloves',
#  'salt',
#  'ground black pepper',
#  '2 garlic cloves',
#  '3 eggs',
#  '1/4 red onion',
#  '1 garlic clove',
#  '1/4 red bell pepper',
#  '1 zucchini',
#  '1 fresh jalapeu00f1o',
#  '1 yellow onion',
#  '3 garlic cloves',
#  '1 egg',
#  'ground black pepper',
#  'pepper',
#  '8 cherry tomatoes',
#  '1 red onion',
#  '1/2 lemon',
#  '1/2 pomegranate',
#  'sea salt',
#  'ground black pepper',
#  'salt',
#  'ground black pepper',
#  '1 egg',
#  '1 lemon',
#  'pepper',
#  '1 lemon cut into wedges',
#  '4 large eggs',
#  '2 yellow onions',
#  '2 garlic cloves',
#  'pepper',
#  'salt',
#  '1 red chili pepper',
#  '1 white onion',
#  '2 garlic cloves',
#  '2 fresh jalapeu00f1os',
#  '8 eggs',
#  '1 avocado',
#  '2 large eggs',
#  '1/2 avocado',
#  '1 tomato',
#  '1 fresh jalapeu00f1o',
#  '1/2 red onion',
#  '1/4 red bell pepper',
#  '1 lime',
#  '6 large eggs',
#  '2 large eggs',
#  'salt and pepper',
#  '1/2 avocado',
#  '1 tomato',
#  '6 cherry tomatoes',
#  '1 garlic clove',
#  'salt',
#  'pepper',
#  '2 large eggs',
#  '1/2 yellow onion',
#  'salt',
#  'pepper',
#  '2 beets',
#  '1 carrot',
#  '2 garlic cloves',
#  'ground black pepper',
#  '1 yellow onion',
#  '1 garlic clove',
#  'salt',
#  'ground black pepper',
#  '1 carrot',
#  'pepper',
#  '4 portobello mushrooms',
#  '4 Romaine lettuce',
#  '2 tomatoes',
#  '4 garlic cloves',
#  '1 zucchini',
#  '2 garlic cloves',
#  'salt',
#  'butter',
#  'pepper',
#  '1 red onion',
#  'salt and pepper',
#  '4 garlic cloves',
#  '2 avocados',
#  '4 eggs',
#  'salt and pepper',
#  '4 cherry tomatoes',
#  '1 egg',
#  'salt',
#  '2 large eggs',
#  'salt and ground black pepper to taste',
#  'pickled jalapeu00f1os',
#  'salt',
#  '2 red onions',
#  'ground black pepper',
#  'salt',
#  'ground black pepper',
#  '1 egg',
#  '1 lemon',
#  'salt',
#  'ground black pepper',
#  '1 egg',
#  '1 lemon',
#  'salt',
#  'fresh rosemary',
#  'salt and pepper',
#  '2 egg yolks',
#  'fresh mint',
#  '1 yellow onion',
#  'pepper',
#  '2 eggs',
#  '3 garlic cloves',
#  'salt',
#  'pepper',
#  '1 red bell pepper',
#  '4 tomatoes',
#  'salt and ground black pepper',
#  '1 garlic clove',
#  'salt',
#  '8 eggs',
#  'fresh basil (optional)',
#  'ground black pepper',
#  'pepper',
#  '5 eggs',
#  '2 egg yolks',
#  'fresh mint',
#  '2 yellow onions',
#  'salt and pepper',
#  '4 egg yolks (optional)',
#  'fresh parsley',
#  '1 Romaine lettuce',
#  '2 garlic cloves',
#  'fresh cilantro',
#  '3 garlic cloves',
#  'salt and ground black pepper',
#  '2 red bell peppers',
#  '2 scallions',
#  '4 large eggs',
#  '1 yellow onion',
#  'pepper',
#  '2 yellow onions',
#  '4 garlic cloves',
#  '1 lemon',
#  '2 garlic cloves',
#  '2 egg whites',
#  '3 garlic cloves',
#  '1 Romaine lettuce',
#  '2 tomatoes',
#  '1/2 red onion',
#  'salt and ground black pepper',
#  '2 scallions',
#  '3 eggs',
#  '2 + <span class=ingredient-optional>1 (optional)</span> limes',
#  '4 egg yolks',
#  '24 fresh redcurrants (optional)',
#  '2 garlic cloves',
#  '2 white onions',
#  'salt and ground black pepper',
#  'salt',
#  'pepper',
#  'sea salt and ground black pepper',
#  '2 scallions',
#  '2 garlic cloves',
#  '2 garlic cloves',
#  'salt',
#  'ground black pepper',
#  '1 yellow onion',
#  'pepper',
#  '2 eggs',
#  '2 egg whites',
#  '1 garlic clove',
#  'salt and ground black pepper',
#  '1 carrot',
#  '1 fresh fennel',
#  '2 shallots',
#  '5 garlic cloves',
#  '1 bay leaf',
#  'ground black pepper',
#  '1 egg',
#  '5 cm) cubes',
#  '1 yellow onion',
#  'carrot roughly chopped  (optional)',
#  '1 whole garlic unpeeled & slightly crushed  (optional)',
#  'fresh thyme or fresh parsley',
#  'water',
#  '1 large head Romaine lettuce',
#  '1/2 lemon',
#  '2 garlic cloves',
#  '1/4 lemon',
#  'salt and pepper',
#  '1 butterhead lettuce',
#  '8 cherry tomatoes',
#  '4 eggs',
#  'olives (optional)',
#  'salt',
#  'ground black pepper',
#  '8 wooden skewers',
#  'salt to taste',
#  'sea salt and ground black pepper',
#  '2 garlic cloves',
#  '1/2 lemon',
#  'pepper',
#  '8 eggs',
#  '1 yellow onion',
#  '3 eggs',
#  '4 chicken breasts',
#  'sea salt',
#  '4 portobello mushrooms',
#  '1 fresh jalapeu00f1o',
#  '2 garlic cloves',
#  '1 shallot',
#  '1 avocado',
#  '1 lemon',
#  'pepper',
#  '3 eggs',
#  '2 lime leaves',
#  '3 garlic cloves',
#  '1 red onion',
#  '2 tomatoes',
#  'salt and ground black pepper to taste ',
#  'salt and ground black pepper',
#  '3 garlic cloves',
#  'fresh basil',
#  '2 garlic cloves',
#  '2 tomatoes',
#  'salt',
#  '1 avocado',
#  '1 lime',
#  'ground black pepper',
#  '2 carrots',
#  '1 avocado',
#  'ground black pepper',
#  'vanilla extract (optional)',
#  '1 avocado',
#  '1 lime',
#  '4 large',
#  '1 garlic clove',
#  '4 egg whites',
#  '4 almond extract',
#  '4 egg yolks',
#  '2 eggs',
#  'salt and pepper',
#  '4 yellow beets',
#  'salt and pepper',
#  '6 popsicle molds',
#  '1 big garlic clove',
#  'salt and ground black pepper',
#  'sea salt',
#  '25 olives',
#  '4 fresh basil',
#  'ground black pepper',
#  '1/4 yellow onion',
#  '4 eggs',
#  '1 lime (optional)',
#  '1 avocado',
#  '1 tomato',
#  '1 garlic clove',
#  '1 lemon',
#  'salt and ground black pepper',
#  'sea salt',
#  '12 fresh strawberries',
#  '20 fresh basil',
#  '10 salami',
#  'ground black pepper',
#  'salt',
#  '5 garlic cloves',
#  '1 green bell pepper',
#  '1 red onion',
#  '4 skewers (metal or wooden)',
#  'salt and ground black pepper',
#  '1 lemon',
#  '2 avocados',
#  '1/2 red onion',
#  '4 ripe avocados',
#  '1/2 red chili pepper',
#  'salt or fish sauce to taste ',
#  '5 garlic cloves',
#  'water',
#  'salt',
#  'ground black pepper',
#  'olive oil (optional)',
#  '1 avocado',
#  '1 scallion',
#  '2 yellow onions',
#  '6 eggs',
#  'salt and pepper',
#  '2 eggs',
#  'salt and pepper',
#  '1/2 red onion',
#  'sea salt and ground black pepper',
#  '2 garlic cloves',
#  '1 lime in wedges',
#  '4 skewers (metal or wooden)',
#  '1 red bell pepper',
#  '10 garlic cloves',
#  '1 yellow onion',
#  '1 vegetable bouillon cube',
#  'salt',
#  'pepper',
#  'ground black pepper',
#  '2 bay leaves',
#  '2 meat bouillon cubes',
#  '1 leek',
#  'salt',
#  'ground black pepper',
#  '2 garlic cloves',
#  '1 star anise',
#  'pepper',
#  '1 small red bell pepper',
#  '1 small zucchini',
#  '1 small summer squash',
#  '2 garlic cloves',
#  '2 diagonally sliced scallions',
#  'sea salt and ground black pepper',
#  '20 cherry tomatoes',
#  '2 tomatoes',
#  '1 garlic clove',
#  '4 large eggs',
#  '3 celery stalks',
#  '1/2 red onion',
#  '1/4 red onion',
#  '1 fresh jalapeu00f1o',
#  '1 tomato',
#  '1 avocado',
#  '1 butterhead lettuce',
#  '8 slices cheddar cheese',
#  '4 egg yolks',
#  'water',
#  'pepper',
#  '1 yellow onion',
#  'salt and pepper',
#  '4 egg whites',
#  '4 large eggs',
#  'salt and pepper',
#  '1/2 scallion',
#  '1 large celery stalk',
#  '3 chicken bouillon cubes',
#  '2 room temperature egg yolks',
#  '3 large eggs',
#  '1 scallion',
#  '1 garlic clove',
#  'salt and pepper',
#  '3 egg whites',
#  '6 limes',
#  '6 egg yolks',
#  '2 egg yolks',
#  '1 garlic clove',
#  'ground black pepper',
#  'water',
#  '2 bay leaves',
#  '1 fresh dill bunch',
#  '1 yellow onion',
#  '1 carrot',
#  'salt and pepper',
#  '2 carrots',
#  '1 yellow onion',
#  '1 leek',
#  '2 bay leaves',
#  'salt',
#  'pepper',
#  '2 egg yolks',
#  '1 yellow onion',
#  '1 fish bouillon cube (optional)',
#  'water',
#  'salt',
#  '3 eggs',
#  'pepper',
#  '1 lemon',
#  '5 eggs',
#  'pepper',
#  '6 egg yolks',
#  '8 eggs',
#  'liquid sweetener',
#  '1 lemon',
#  '2 large eggs',
#  'ice cube and water',
#  'ground nutmeg',
#  'salt and ground black pepper',
#  '6 eggs',
#  '2 garlic cloves',
#  'pepper',
#  '4 scallions',
#  '1/2 red onion',
#  '4 garlic cloves',
#  '1 medium yellow onion',
#  '3 garlic cloves',
#  '4 eggs',
#  'sea salt (optional)',
#  '1 red onion',
#  'salt',
#  'pepper',
#  '12 large eggs',
#  'salt',
#  'pepper',
#  '2 ripe avocados',
#  '4 portobello mushrooms',
#  '2 tomatoes',
#  'salt',
#  '1 egg',
#  'pepper',
#  '2 garlic cloves',
#  '1 yellow onion',
#  '1 avocado',
#  'fresh cilantro',
#  '1 yellow onion',
#  '2 garlic cloves',
#  'salt or ground black pepper',
#  '1 lime',
#  '1 egg',
#  '4 yellow onions',
#  'pepper',
#  '4 chicken breasts',
#  ...]

# %%
ingredients_no_measure_clean = pd.Series(ingredients_no_measure_clean)
ingredients_no_measure_clean
# Out:
# 0                               3 large eggs
# 1                            salt and pepper
# 2       salt or ground black pepper to taste
# 3               salt and ground black pepper
# 4                              salt to taste
#                         ...
# 7109                         iceberg lettuce
# 7110                                1 tomato
# 7111                               1 avocado
# 7112                             poppy seeds
# 7113                                sea salt
# Length: 7114, dtype: object

# %%
ingredients_no_measure_clean.str.extract(r"(?P<amount>[0-9]/?[0-9]?)?[\s]?(?P<name>.+)",flags=re.I)
# Out:
#      amount                                  name
# 0         3                            large eggs
# 1       NaN                       salt and pepper
# 2       NaN  salt or ground black pepper to taste
# 3       NaN          salt and ground black pepper
# 4       NaN                         salt to taste
# ...     ...                                   ...
# 7109    NaN                       iceberg lettuce
# 7110      1                                tomato
# 7111      1                               avocado
# 7112    NaN                           poppy seeds
# 7113    NaN                              sea salt
#
# [7114 rows x 2 columns]
